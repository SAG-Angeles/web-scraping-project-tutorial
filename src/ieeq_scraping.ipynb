# %%
import requests
from bs4 import Beautyfuloup
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import requests
# ----> 2 from bs4 import Beautyfuloup
#       3 import pandas as pd
#
# ImportError: cannot import name 'Beautyfuloup' from 'bs4' (/home/vscode/.local/lib/python3.11/site-packages/bs4/__init__.py)
