# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://ieeq.mx/contenido/elecciones/2023_2024/resultados/#/home/ayu/detalle-cas/Amealco%20de%20Bonfil"

response = requests.get(url, headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36"})
response
# Out:
# <Response [200]>

# %%
bs = BeautifulSoup(response.content, "html.parser")
bs
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-41848526-1"></script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', 'UA-41848526-1');
#   </script>
# <!-- GMR -->
# <meta charset="utf-8"/>
# <title>Resultados Electorales Locales 2024 - Instituto Electoral del Estado de Querétaro </title>
# <base href="./"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Resultados Electorales Locales 2024, Elecciones Estatales de Querétaro." name="description"/>
# <meta content="querétaro,elecciones,diputación,ayuntamiento,resultados electorales locales,voto,2 de junio,ieeq,ine" name="keywords"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="assets/css/fonts.css" rel="stylesheet"/>
# <link href="assets/css/bootstrap/bootstrap.min.css" rel="stylesheet"/>
# <link href="assets/css/fontawesome/all.min.css" rel="stylesheet"/>
# <link href="assets/css/main.css" rel="stylesheet"/>
# <link href="styles.ee64797111b3c1c1608e.css" rel="stylesheet"/>
# <script id="spt-HS" src="https://pel.eleccionesqro.mx/js/HubSpot/codSeg.js"></script>
# </head>
# <body class="bg-clr">
# <sfx-root></sfx-root>
# <script src="assets/js/jquery/jquery-3.5.1.min.js"></script>
# <script src="assets/js/bootstrap/bootstrap.bundle.min.js"></script>
# <script src="assets/js/main.js"></script>
# <script defer="" src="runtime.28e27a40efd4f5c3aa86.js"></script><script defer="" src="polyfills.7a965888daba3fbc4385.js"></script><script defer="" src="scripts.2ac87d7e050e46d65232.js"></script><script defer="" src="main.53da7bd8e4638ac18e57.js"></script></body>
# </html>

# %%
tabla = bs.find("table", class_="table")
filas = bs.find_all("td")
tabla
